# %% [markdown]
# # Analyze (keep + skip) no mean

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file
df = pd.read_csv('/content/arcade_sample_level_audio_metrics.csv')

# Create figure with subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('Audio Quality Comparison: Before vs After Filtering\n(Keep vs Skip)',
             fontsize=16, fontweight='bold')

# Separate data by keep_or_skip
keep_data = df[df['keep_or_skip'] == 'Keep']
skip_data = df[df['keep_or_skip'] == 'Skip']

# Define colors
skip_color = '#ff6b6b'
keep_color = '#51cf66'

# 1. Duration Distribution (Top Left)
ax1 = axes[0, 0]
ax1.hist([skip_data['duration'], keep_data['duration']],
         bins=30, label=['Skip', 'Keep'],
         color=[skip_color, keep_color], alpha=0.7, edgecolor='black')
ax1.set_xlabel('Duration (seconds)', fontsize=18)
ax1.set_ylabel('Density', fontsize=18)
ax1.legend()
ax1.grid(True, alpha=0.3)

# Add vertical lines for means
skip_mean_duration = skip_data['duration'].mean()
keep_mean_duration = keep_data['duration'].mean()
ax1.axvline(skip_mean_duration, color=skip_color, linestyle='--', linewidth=2)
ax1.axvline(keep_mean_duration, color=keep_color, linestyle='--', linewidth=2)

# 2. SNR Distribution (Top Middle)
ax2 = axes[0, 1]
ax2.hist([skip_data['snr_db'], keep_data['snr_db']],
         bins=30, label=['Skip', 'Keep'],
         color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax2.set_xlabel('SNR (dB)', fontsize=18)
ax2.set_ylabel('Density', fontsize=18)
ax2.legend()
ax2.grid(True, alpha=0.3)

# Add vertical lines for means
skip_mean_snr = skip_data['snr_db'].mean()
keep_mean_snr = keep_data['snr_db'].mean()
ax2.axvline(skip_mean_snr, color=skip_color, linestyle='--', linewidth=2)
ax2.axvline(keep_mean_snr, color=keep_color, linestyle='--', linewidth=2)

# 3. Clipping Rate Distribution (Top Right)
ax3 = axes[0, 2]
ax3.hist([skip_data['clipping_rate'], keep_data['clipping_rate']],
         bins=30, label=['Skip', 'Keep'],
         color=[skip_color, keep_color], alpha=0.7, edgecolor='black')
ax3.set_xlabel('Clipping Rate (%)', fontsize=18)
ax3.set_ylabel('Density', fontsize=18)
ax3.legend()
ax3.grid(True, alpha=0.3)

# Add vertical lines for means
skip_mean_clip = skip_data['clipping_rate'].mean()
keep_mean_clip = keep_data['clipping_rate'].mean()
ax3.axvline(skip_mean_clip, color=skip_color, linestyle='--', linewidth=2)
ax3.axvline(keep_mean_clip, color=keep_color, linestyle='--', linewidth=2)

# 4. Silence Ratio Distribution (Bottom Left)
ax4 = axes[1, 0]
ax4.hist([skip_data['silence_ratio'], keep_data['silence_ratio']],
         bins=30, label=['Skip', 'Keep'],
         color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax4.set_xlabel('Silence Ratio (%)', fontsize=18)
ax4.set_ylabel('Density', fontsize=18)
ax4.legend()
ax4.grid(True, alpha=0.3)

# Add vertical lines for means
skip_mean_silence = skip_data['silence_ratio'].mean()
keep_mean_silence = keep_data['silence_ratio'].mean()
ax4.axvline(skip_mean_silence, color=skip_color, linestyle='--', linewidth=2)
ax4.axvline(keep_mean_silence, color=keep_color, linestyle='--', linewidth=2)

# 5. Dynamic Range Distribution (Bottom Middle)
ax5 = axes[1, 1]
ax5.hist([skip_data['dynamic_range'], keep_data['dynamic_range']],
         bins=30, label=['Skip', 'Keep'],
         color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax5.set_xlabel('Dynamic Range (dB)', fontsize=18)
ax5.set_ylabel('Density', fontsize=18)
ax5.legend()
ax5.grid(True, alpha=0.3)

# Add vertical lines for means
skip_mean_dr = skip_data['dynamic_range'].mean()
keep_mean_dr = keep_data['dynamic_range'].mean()
ax5.axvline(skip_mean_dr, color=skip_color, linestyle='--', linewidth=2)
ax5.axvline(keep_mean_dr, color=keep_color, linestyle='--', linewidth=2)

# 6. Spectral Centroid Distribution (Bottom Right)
ax6 = axes[1, 2]
ax6.hist([skip_data['spectral_centroid'], keep_data['spectral_centroid']],
         bins=30, label=['Skip', 'Keep'],
         color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax6.set_xlabel('Spectral Centroid (Hz)', fontsize=18)
ax6.set_ylabel('Density', fontsize=18)
ax6.legend()
ax6.grid(True, alpha=0.3)

# Add vertical lines for means
skip_mean_sc = skip_data['spectral_centroid'].mean()
keep_mean_sc = keep_data['spectral_centroid'].mean()
ax6.axvline(skip_mean_sc, color=skip_color, linestyle='--', linewidth=2)
ax6.axvline(keep_mean_sc, color=keep_color, linestyle='--', linewidth=2)

plt.tight_layout()

# Save the complete figure
plt.savefig('audio_quality_comparison_all.pdf', dpi=300, bbox_inches='tight')
print("Saved: audio_quality_comparison_all.pdf")

# Now create individual plots
# 1. Duration
fig1, ax = plt.subplots(figsize=(8, 6))
ax.hist([skip_data['duration'], keep_data['duration']],
        bins=30, label=['Skip', 'Keep'],
        color=[skip_color, keep_color], alpha=0.7, edgecolor='black')
ax.set_xlabel('Duration (seconds)', fontsize=18)
ax.set_ylabel('Density', fontsize=18)
ax.set_title('Duration Distribution: Keep vs Skip', fontsize=14, fontweight='bold')
ax.legend(fontsize=18)
ax.grid(True, alpha=0.3)
ax.axvline(skip_mean_duration, color=skip_color, linestyle='--', linewidth=2)
ax.axvline(keep_mean_duration, color=keep_color, linestyle='--', linewidth=2)
plt.tight_layout()
plt.savefig('duration_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: duration_distribution.pdf")
plt.close()

# 2. SNR
fig2, ax = plt.subplots(figsize=(8, 6))
ax.hist([skip_data['snr_db'], keep_data['snr_db']],
        bins=30, label=['Skip', 'Keep'],
        color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax.set_xlabel('SNR (dB)', fontsize=18)
ax.set_ylabel('Density', fontsize=18)
ax.set_title('SNR Distribution: Keep vs Skip', fontsize=14, fontweight='bold')
ax.legend(fontsize=18)
ax.grid(True, alpha=0.3)
ax.axvline(skip_mean_snr, color=skip_color, linestyle='--', linewidth=2)
ax.axvline(keep_mean_snr, color=keep_color, linestyle='--', linewidth=2)
plt.tight_layout()
plt.savefig('snr_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: snr_distribution.pdf")
plt.close()

# 3. Clipping Rate
fig3, ax = plt.subplots(figsize=(8, 6))
ax.hist([skip_data['clipping_rate'], keep_data['clipping_rate']],
        bins=30, label=['Skip', 'Keep'],
        color=[skip_color, keep_color], alpha=0.7, edgecolor='black')
ax.set_xlabel('Clipping Rate (%)', fontsize=18)
ax.set_ylabel('Density', fontsize=18)
ax.set_title('Clipping Rate Distribution: Keep vs Skip', fontsize=14, fontweight='bold')
ax.legend(fontsize=18)
ax.grid(True, alpha=0.3)
ax.axvline(skip_mean_clip, color=skip_color, linestyle='--', linewidth=2)
ax.axvline(keep_mean_clip, color=keep_color, linestyle='--', linewidth=2)
plt.tight_layout()
plt.savefig('clipping_rate_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: clipping_rate_distribution.pdf")
plt.close()

# 4. Silence Ratio
fig4, ax = plt.subplots(figsize=(8, 6))
ax.hist([skip_data['silence_ratio'], keep_data['silence_ratio']],
        bins=30, label=['Skip', 'Keep'],
        color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax.set_xlabel('Silence Ratio (%)', fontsize=18)
ax.set_ylabel('Density', fontsize=18)
ax.set_title('Silence Ratio Distribution: Keep vs Skip', fontsize=14, fontweight='bold')
ax.legend(fontsize=18)
ax.grid(True, alpha=0.3)
ax.axvline(skip_mean_silence, color=skip_color, linestyle='--', linewidth=2)
ax.axvline(keep_mean_silence, color=keep_color, linestyle='--', linewidth=2)
plt.tight_layout()
plt.savefig('silence_ratio_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: silence_ratio_distribution.pdf")
plt.close()

# 5. Dynamic Range
fig5, ax = plt.subplots(figsize=(8, 6))
ax.hist([skip_data['dynamic_range'], keep_data['dynamic_range']],
        bins=30, label=['Skip', 'Keep'],
        color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax.set_xlabel('Dynamic Range (dB)', fontsize=18)
ax.set_ylabel('Density', fontsize=18)
ax.set_title('Dynamic Range Distribution: Keep vs Skip', fontsize=14, fontweight='bold')
ax.legend(fontsize=18)
ax.grid(True, alpha=0.3)
ax.axvline(skip_mean_dr, color=skip_color, linestyle='--', linewidth=2)
ax.axvline(keep_mean_dr, color=keep_color, linestyle='--', linewidth=2)
plt.tight_layout()
plt.savefig('dynamic_range_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: dynamic_range_distribution.pdf")
plt.close()

# 6. Spectral Centroid
fig6, ax = plt.subplots(figsize=(8, 6))
ax.hist([skip_data['spectral_centroid'], keep_data['spectral_centroid']],
        bins=30, label=['Skip', 'Keep'],
        color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax.set_xlabel('Spectral Centroid (Hz)', fontsize=18)
ax.set_ylabel('Density', fontsize=18)
ax.set_title('Spectral Centroid Distribution: Keep vs Skip', fontsize=14, fontweight='bold')
ax.legend(fontsize=18)
ax.grid(True, alpha=0.3)
ax.axvline(skip_mean_sc, color=skip_color, linestyle='--', linewidth=2)
ax.axvline(keep_mean_sc, color=keep_color, linestyle='--', linewidth=2)
plt.tight_layout()
plt.savefig('spectral_centroid_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: spectral_centroid_distribution.pdf")
plt.close()

print("\nAll graphs have been generated and saved!")
print("\nFiles created:")
print("1. audio_quality_comparison_all.pdf (combined view)")
print("2. duration_distribution.pdf")
print("3. snr_distribution.pdf")
print("4. clipping_rate_distribution.pdf")
print("5. silence_ratio_distribution.pdf")
print("6. dynamic_range_distribution.pdf")
print("7. spectral_centroid_distribution.pdf")
# Out:
# Saved: audio_quality_comparison_all.png
# Saved: duration_distribution.png
# Saved: snr_distribution.png
# Saved: clipping_rate_distribution.png
# Saved: silence_ratio_distribution.png
# Saved: dynamic_range_distribution.png
# Saved: spectral_centroid_distribution.png
#
# All graphs have been generated and saved!
#
# Files created:
# 1. audio_quality_comparison_all.png (combined view)
# 2. duration_distribution.png
# 3. snr_distribution.png
# 4. clipping_rate_distribution.png
# 5. silence_ratio_distribution.png
# 6. dynamic_range_distribution.png
# 7. spectral_centroid_distribution.png

# %% [markdown]
# # Analyze (skip + keep) mean lines

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file
df = pd.read_csv('/content/arcade_sample_level_audio_metrics.csv')

# Clean column names and data
df.columns = df.columns.str.strip()
df['keep_or_skip'] = df['keep_or_skip'].str.strip()

# Separate data by keep_or_skip
keep_data = df[df['keep_or_skip'] == 'Keep']
skip_data = df[df['keep_or_skip'] == 'Skip']

print(f"Keep data: {len(keep_data)} rows")
print(f"Skip data: {len(skip_data)} rows")

# Define colors
skip_color = '#ff6b6b'
keep_color = '#51cf66'

# Create figure with 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Audio Quality Comparison: Before vs After Filtering\n(Keep vs Skip)',
             fontsize=16, fontweight='bold')

# 1. SNR Distribution (Top Left)
ax1 = axes[0, 0]
ax1.hist([skip_data['snr_db'], keep_data['snr_db']],
         bins=30, label=['Skip', 'Keep'],
         color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax1.set_xlabel('SNR (dB)', fontsize=11)
ax1.set_ylabel('Density', fontsize=11)
ax1.grid(True, alpha=0.3)

skip_mean_snr = skip_data['snr_db'].mean()
keep_mean_snr = keep_data['snr_db'].mean()
ax1.axvline(skip_mean_snr, color=skip_color, linestyle='--', linewidth=2)
ax1.axvline(keep_mean_snr, color=keep_color, linestyle='--', linewidth=2)

from matplotlib.patches import Patch
from matplotlib.lines import Line2D
legend_elements = [
    Patch(facecolor=skip_color, edgecolor='black', label=f'Skip'),
    Patch(facecolor=keep_color, edgecolor='black', label=f'Keep'),
    Line2D([0], [0], color=skip_color, linestyle='--', linewidth=2, label=f'Skip Mean: {skip_mean_snr:.2f}'),
    Line2D([0], [0], color=keep_color, linestyle='--', linewidth=2, label=f'Keep Mean: {keep_mean_snr:.2f}')
]
ax1.legend(handles=legend_elements, loc='upper right', fontsize=9)

# 2. Silence Ratio Distribution (Top Right)
ax2 = axes[0, 1]
ax2.hist([skip_data['silence_ratio'], keep_data['silence_ratio']],
         bins=30, label=['Skip', 'Keep'],
         color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax2.set_xlabel('Silence Ratio (%)', fontsize=11)
ax2.set_ylabel('Density', fontsize=11)
ax2.grid(True, alpha=0.3)

skip_mean_silence = skip_data['silence_ratio'].mean()
keep_mean_silence = keep_data['silence_ratio'].mean()
ax2.axvline(skip_mean_silence, color=skip_color, linestyle='--', linewidth=2)
ax2.axvline(keep_mean_silence, color=keep_color, linestyle='--', linewidth=2)

legend_elements = [
    Patch(facecolor=skip_color, edgecolor='black', label=f'Skip'),
    Patch(facecolor=keep_color, edgecolor='black', label=f'Keep'),
    Line2D([0], [0], color=skip_color, linestyle='--', linewidth=2, label=f'Skip Mean: {skip_mean_silence:.2f}'),
    Line2D([0], [0], color=keep_color, linestyle='--', linewidth=2, label=f'Keep Mean: {keep_mean_silence:.2f}')
]
ax2.legend(handles=legend_elements, loc='upper right', fontsize=9)

# 3. Dynamic Range Distribution (Bottom Left)
ax3 = axes[1, 0]
ax3.hist([skip_data['dynamic_range'], keep_data['dynamic_range']],
         bins=30, label=['Skip', 'Keep'],
         color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax3.set_xlabel('Dynamic Range (dB)', fontsize=11)
ax3.set_ylabel('Density', fontsize=11)
ax3.grid(True, alpha=0.3)

skip_mean_dr = skip_data['dynamic_range'].mean()
keep_mean_dr = keep_data['dynamic_range'].mean()
ax3.axvline(skip_mean_dr, color=skip_color, linestyle='--', linewidth=2)
ax3.axvline(keep_mean_dr, color=keep_color, linestyle='--', linewidth=2)

legend_elements = [
    Patch(facecolor=skip_color, edgecolor='black', label=f'Skip'),
    Patch(facecolor=keep_color, edgecolor='black', label=f'Keep'),
    Line2D([0], [0], color=skip_color, linestyle='--', linewidth=2, label=f'Skip Mean: {skip_mean_dr:.2f}'),
    Line2D([0], [0], color=keep_color, linestyle='--', linewidth=2, label=f'Keep Mean: {keep_mean_dr:.2f}')
]
ax3.legend(handles=legend_elements, loc='upper right', fontsize=9)

# 4. Spectral Centroid Distribution (Bottom Right)
ax4 = axes[1, 1]
ax4.hist([skip_data['spectral_centroid'], keep_data['spectral_centroid']],
         bins=30, label=['Skip', 'Keep'],
         color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax4.set_xlabel('Spectral Centroid (Hz)', fontsize=11)
ax4.set_ylabel('Density', fontsize=11)
ax4.grid(True, alpha=0.3)

skip_mean_sc = skip_data['spectral_centroid'].mean()
keep_mean_sc = keep_data['spectral_centroid'].mean()
ax4.axvline(skip_mean_sc, color=skip_color, linestyle='--', linewidth=2)
ax4.axvline(keep_mean_sc, color=keep_color, linestyle='--', linewidth=2)

legend_elements = [
    Patch(facecolor=skip_color, edgecolor='black', label=f'Skip'),
    Patch(facecolor=keep_color, edgecolor='black', label=f'Keep'),
    Line2D([0], [0], color=skip_color, linestyle='--', linewidth=2, label=f'Skip Mean: {skip_mean_sc:.2f}'),
    Line2D([0], [0], color=keep_color, linestyle='--', linewidth=2, label=f'Keep Mean: {keep_mean_sc:.2f}')
]
ax4.legend(handles=legend_elements, loc='upper right', fontsize=9)

plt.tight_layout()

# Save the complete figure
plt.savefig('audio_quality_comparison_4metrics.pdf', dpi=300, bbox_inches='tight')
print("Saved: audio_quality_comparison_4metrics.pdf")

# Now create individual plots with enhanced legends
# 1. SNR
fig1, ax = plt.subplots(figsize=(10, 6))
ax.hist([skip_data['snr_db'], keep_data['snr_db']],
        bins=30,
        color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax.set_xlabel('SNR (dB)', fontsize=18)
ax.set_ylabel('Density', fontsize=18)
ax.set_title('SNR Distribution: Keep vs Skip', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.axvline(skip_mean_snr, color=skip_color, linestyle='--', linewidth=2.5)
ax.axvline(keep_mean_snr, color=keep_color, linestyle='--', linewidth=2.5)

legend_elements = [
    Patch(facecolor=skip_color, edgecolor='black', label=f'Skip'),
    Patch(facecolor=keep_color, edgecolor='black', label=f'Keep'),
    Line2D([0], [0], color=skip_color, linestyle='--', linewidth=2.5, label=f'Skip Mean: {skip_mean_snr:.2f}'),
    Line2D([0], [0], color=keep_color, linestyle='--', linewidth=2.5, label=f'Keep Mean: {keep_mean_snr:.2f}')
]
ax.legend(handles=legend_elements, loc='upper right', fontsize=11)
plt.tight_layout()
plt.savefig('snr_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: snr_distribution.pdf")
plt.close()

# 2. Silence Ratio
fig2, ax = plt.subplots(figsize=(10, 6))
ax.hist([skip_data['silence_ratio'], keep_data['silence_ratio']],
        bins=30,
        color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax.set_xlabel('Silence Ratio (%)', fontsize=18)
ax.set_ylabel('Density', fontsize=18)
ax.set_title('Silence Ratio Distribution: Keep vs Skip', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.axvline(skip_mean_silence, color=skip_color, linestyle='--', linewidth=2.5)
ax.axvline(keep_mean_silence, color=keep_color, linestyle='--', linewidth=2.5)

legend_elements = [
    Patch(facecolor=skip_color, edgecolor='black', label=f'Skip'),
    Patch(facecolor=keep_color, edgecolor='black', label=f'Keep'),
    Line2D([0], [0], color=skip_color, linestyle='--', linewidth=2.5, label=f'Skip Mean: {skip_mean_silence:.2f}'),
    Line2D([0], [0], color=keep_color, linestyle='--', linewidth=2.5, label=f'Keep Mean: {keep_mean_silence:.2f}')
]
ax.legend(handles=legend_elements, loc='upper right', fontsize=11)
plt.tight_layout()
plt.savefig('silence_ratio_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: silence_ratio_distribution.pdf")
plt.close()

# 3. Dynamic Range
fig3, ax = plt.subplots(figsize=(10, 6))
ax.hist([skip_data['dynamic_range'], keep_data['dynamic_range']],
        bins=30,
        color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax.set_xlabel('Dynamic Range (dB)', fontsize=18)
ax.set_ylabel('Density', fontsize=18)
ax.set_title('Dynamic Range Distribution: Keep vs Skip', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.axvline(skip_mean_dr, color=skip_color, linestyle='--', linewidth=2.5)
ax.axvline(keep_mean_dr, color=keep_color, linestyle='--', linewidth=2.5)

legend_elements = [
    Patch(facecolor=skip_color, edgecolor='black', label=f'Skip'),
    Patch(facecolor=keep_color, edgecolor='black', label=f'Keep'),
    Line2D([0], [0], color=skip_color, linestyle='--', linewidth=2.5, label=f'Skip Mean: {skip_mean_dr:.2f}'),
    Line2D([0], [0], color=keep_color, linestyle='--', linewidth=2.5, label=f'Keep Mean: {keep_mean_dr:.2f}')
]
ax.legend(handles=legend_elements, loc='upper right', fontsize=11)
plt.tight_layout()
plt.savefig('dynamic_range_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: dynamic_range_distribution.pdf")
plt.close()

# 4. Spectral Centroid
fig4, ax = plt.subplots(figsize=(10, 6))
ax.hist([skip_data['spectral_centroid'], keep_data['spectral_centroid']],
        bins=30,
        color=[skip_color, keep_color], alpha=0.7, edgecolor='black', density=True)
ax.set_xlabel('Spectral Centroid (Hz)', fontsize=18)
ax.set_ylabel('Density', fontsize=18)
ax.set_title('Spectral Centroid Distribution: Keep vs Skip', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.axvline(skip_mean_sc, color=skip_color, linestyle='--', linewidth=2.5)
ax.axvline(keep_mean_sc, color=keep_color, linestyle='--', linewidth=2.5)

legend_elements = [
    Patch(facecolor=skip_color, edgecolor='black', label=f'Skip'),
    Patch(facecolor=keep_color, edgecolor='black', label=f'Keep'),
    Line2D([0], [0], color=skip_color, linestyle='--', linewidth=2.5, label=f'Skip Mean: {skip_mean_sc:.2f}'),
    Line2D([0], [0], color=keep_color, linestyle='--', linewidth=2.5, label=f'Keep Mean: {skip_mean_sc:.2f}')
]
ax.legend(handles=legend_elements, loc='upper right', fontsize=11)
plt.tight_layout()
plt.savefig('spectral_centroid_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: spectral_centroid_distribution.pdf")
plt.close()

print("\nAll graphs have been generated and saved!")
print("\nFiles created:")
print("1. audio_quality_comparison_4metrics.pdf (combined 2x2 view)")
print("2. snr_distribution.pdf")
print("3. silence_ratio_distribution.pdf")
print("4. dynamic_range_distribution.pdf")
print("5. spectral_centroid_distribution.pdf")
# Out:
# Keep data: 4539 rows
# Skip data: 2366 rows
# Saved: audio_quality_comparison_4metrics.pdf
# Saved: snr_distribution.pdf
# Saved: silence_ratio_distribution.pdf
# Saved: dynamic_range_distribution.pdf
# Saved: spectral_centroid_distribution.pdf
#
# All graphs have been generated and saved!
#
# Files created:
# 1. audio_quality_comparison_4metrics.pdf (combined 2x2 view)
# 2. snr_distribution.pdf
# 3. silence_ratio_distribution.pdf
# 4. dynamic_range_distribution.pdf
# 5. spectral_centroid_distribution.pdf

# %% [markdown]
# # Full analyze

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file
df = pd.read_csv('/content/arcade_sample_level_audio_metrics.csv')

# Clean column names (remove whitespace)
df.columns = df.columns.str.strip()

print(f"Total rows in dataset: {len(df)}")

# Create figure with 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Audio Quality Distribution - Complete Dataset',
             fontsize=16, fontweight='bold')

# Define color
data_color = '#4a90e2'

# 1. SNR Distribution (Top Left)
ax1 = axes[0, 0]
ax1.hist(df['snr_db'], bins=30, color=data_color, alpha=0.7, edgecolor='black')
ax1.set_xlabel('SNR (dB)', fontsize=18)
ax1.set_ylabel('Frequency', fontsize=18)
ax1.set_title('SNR Distribution', fontsize=18, fontweight='bold')
ax1.grid(True, alpha=0.3)
mean_val = df['snr_db'].mean()
ax1.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax1.legend()

# 2. Silence Ratio Distribution (Top Right)
ax2 = axes[0, 1]
ax2.hist(df['silence_ratio'], bins=30, color=data_color, alpha=0.7, edgecolor='black')
ax2.set_xlabel('Silence Ratio (%)', fontsize=18)
ax2.set_ylabel('Frequency', fontsize=18)
ax2.set_title('Silence Ratio Distribution', fontsize=18, fontweight='bold')
ax2.grid(True, alpha=0.3)
mean_val = df['silence_ratio'].mean()
ax2.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax2.legend()

# 3. Dynamic Range Distribution (Bottom Left)
ax3 = axes[1, 0]
ax3.hist(df['dynamic_range'], bins=30, color=data_color, alpha=0.7, edgecolor='black')
ax3.set_xlabel('Dynamic Range (dB)', fontsize=18)
ax3.set_ylabel('Frequency', fontsize=18)
ax3.set_title('Dynamic Range Distribution', fontsize=18, fontweight='bold')
ax3.grid(True, alpha=0.3)
mean_val = df['dynamic_range'].mean()
ax3.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax3.legend()

# 4. Spectral Centroid Distribution (Bottom Right)
ax4 = axes[1, 1]
ax4.hist(df['spectral_centroid'], bins=30, color=data_color, alpha=0.7, edgecolor='black')
ax4.set_xlabel('Spectral Centroid (Hz)', fontsize=18)
ax4.set_ylabel('Frequency', fontsize=18)
ax4.set_title('Spectral Centroid Distribution', fontsize=18, fontweight='bold')
ax4.grid(True, alpha=0.3)
mean_val = df['spectral_centroid'].mean()
ax4.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax4.legend()

plt.tight_layout()

# Save the complete figure
plt.savefig('audio_quality_complete_dataset_4metrics.pdf', dpi=300, bbox_inches='tight')
print("Saved: audio_quality_complete_dataset_4metrics.pdf")

# Now create individual plots
# 1. SNR
fig1, ax = plt.subplots(figsize=(8, 6))
ax.hist(df['snr_db'], bins=30, color=data_color, alpha=0.7, edgecolor='black')
ax.set_xlabel('SNR (dB)', fontsize=18)
ax.set_ylabel('Frequency', fontsize=18)
ax.set_title('SNR Distribution', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
mean_val = df['snr_db'].mean()
median_val = df['snr_db'].median()
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax.axvline(median_val, color='green', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.legend()
plt.tight_layout()
plt.savefig('snr_distribution_complete.pdf', dpi=300, bbox_inches='tight')
print("Saved: snr_distribution_complete.pdf")
plt.close()

# 2. Silence Ratio
fig2, ax = plt.subplots(figsize=(8, 6))
ax.hist(df['silence_ratio'], bins=30, color=data_color, alpha=0.7, edgecolor='black')
ax.set_xlabel('Silence Ratio (%)', fontsize=18)
ax.set_ylabel('Frequency', fontsize=18)
ax.set_title('Silence Ratio Distribution', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
mean_val = df['silence_ratio'].mean()
median_val = df['silence_ratio'].median()
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax.axvline(median_val, color='green', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.legend()
plt.tight_layout()
plt.savefig('silence_ratio_distribution_complete.pdf', dpi=300, bbox_inches='tight')
print("Saved: silence_ratio_distribution_complete.pdf")
plt.close()

# 3. Dynamic Range
fig3, ax = plt.subplots(figsize=(8, 6))
ax.hist(df['dynamic_range'], bins=30, color=data_color, alpha=0.7, edgecolor='black')
ax.set_xlabel('Dynamic Range (dB)', fontsize=18)
ax.set_ylabel('Frequency', fontsize=18)
ax.set_title('Dynamic Range Distribution', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
mean_val = df['dynamic_range'].mean()
median_val = df['dynamic_range'].median()
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax.axvline(median_val, color='green', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.legend()
plt.tight_layout()
plt.savefig('dynamic_range_distribution_complete.pdf', dpi=300, bbox_inches='tight')
print("Saved: dynamic_range_distribution_complete.pdf")
plt.close()

# 4. Spectral Centroid
fig4, ax = plt.subplots(figsize=(8, 6))
ax.hist(df['spectral_centroid'], bins=30, color=data_color, alpha=0.7, edgecolor='black')
ax.set_xlabel('Spectral Centroid (Hz)', fontsize=18)
ax.set_ylabel('Frequency', fontsize=18)
ax.set_title('Spectral Centroid Distribution', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
mean_val = df['spectral_centroid'].mean()
median_val = df['spectral_centroid'].median()
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax.axvline(median_val, color='green', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.legend()
plt.tight_layout()
plt.savefig('spectral_centroid_distribution_complete.pdf', dpi=300, bbox_inches='tight')
print("Saved: spectral_centroid_distribution_complete.pdf")
plt.close()

# Print summary statistics
print("\n" + "="*50)
print("SUMMARY STATISTICS")
print("="*50)
print(f"\nSNR (dB):")
print(f"  Mean: {df['snr_db'].mean():.2f}, Median: {df['snr_db'].median():.2f}, Std: {df['snr_db'].std():.2f}")
print(f"\nSilence Ratio (%):")
print(f"  Mean: {df['silence_ratio'].mean():.2f}, Median: {df['silence_ratio'].median():.2f}, Std: {df['silence_ratio'].std():.2f}")
print(f"\nDynamic Range (dB):")
print(f"  Mean: {df['dynamic_range'].mean():.2f}, Median: {df['dynamic_range'].median():.2f}, Std: {df['dynamic_range'].std():.2f}")
print(f"\nSpectral Centroid (Hz):")
print(f"  Mean: {df['spectral_centroid'].mean():.2f}, Median: {df['spectral_centroid'].median():.2f}, Std: {df['spectral_centroid'].std():.2f}")

print("\n" + "="*50)
print("All graphs have been generated and saved!")
print("="*50)
print("\nFiles created:")
print("1. audio_quality_complete_dataset_4metrics.pdf (combined 2x2 view)")
print("2. snr_distribution_complete.pdf")
print("3. silence_ratio_distribution_complete.pdf")
print("4. dynamic_range_distribution_complete.pdf")
print("5. spectral_centroid_distribution_complete.pdf")
# Out:
# Total rows in dataset: 6907
# Saved: audio_quality_complete_dataset_4metrics.pdf
# Saved: snr_distribution_complete.pdf
# Saved: silence_ratio_distribution_complete.pdf
# Saved: dynamic_range_distribution_complete.pdf
# Saved: spectral_centroid_distribution_complete.pdf
#
# ...
# SUMMARY STATISTICS
# ...
#
# SNR (dB):
#   Mean: 13.24, Median: 14.21, Std: 9.85
#
# Silence Ratio (%):
#   Mean: 15.98, Median: 10.33, Std: 18.87
#
# Dynamic Range (dB):
#   Mean: 15.83, Median: 15.87, Std: 4.01
#
# Spectral Centroid (Hz):
#   Mean: 1602.30, Median: 1555.82, Std: 401.08
#
# ...
# All graphs have been generated and saved!
# ...
#
# Files created:
# 1. audio_quality_complete_dataset_4metrics.pdf (combined 2x2 view)
# 2. snr_distribution_complete.pdf
# 3. silence_ratio_distribution_complete.pdf
# 4. dynamic_range_distribution_complete.pdf
# 5. spectral_centroid_distribution_complete.pdf

# %% [markdown]
# # Analyze According to cities

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file
df = pd.read_csv('/content/arcade_city_level_audio_metrics.csv')

# Clean column names
df.columns = df.columns.str.strip()

print(f"Total cities in dataset: {len(df)}")
print(f"Columns: {df.columns.tolist()}")

# Create figure with subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('Audio Quality Statistics Across Cities',
             fontsize=16, fontweight='bold')

# Define color
data_color = '#4a90e2'

# 1. Duration Mean Distribution (Top Left)
ax1 = axes[0, 0]
ax1.hist(df['duration_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax1.set_xlabel('Duration Mean (seconds)', fontsize=11)
ax1.set_ylabel('Frequency', fontsize=11)
ax1.set_title('Duration Mean Distribution', fontsize=12, fontweight='bold')
ax1.grid(True, alpha=0.3)
mean_val = df['duration_mean'].mean()
median_val = df['duration_mean'].median()
ax1.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax1.axvline(median_val, color='green', linestyle='--', linewidth=2.5)

from matplotlib.lines import Line2D
legend_elements = [
    Line2D([0], [0], color='red', linestyle='--', linewidth=2.5, label=f'Mean: {mean_val:.2f}'),
    Line2D([0], [0], color='green', linestyle='--', linewidth=2.5, label=f'Median: {median_val:.2f}')
]
ax1.legend(handles=legend_elements, loc='upper right', fontsize=9)

# 2. SNR Mean Distribution (Top Middle)
ax2 = axes[0, 1]
ax2.hist(df['snr_db_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax2.set_xlabel('SNR Mean (dB)', fontsize=11)
ax2.set_ylabel('Frequency', fontsize=11)
ax2.set_title('SNR Mean Distribution', fontsize=12, fontweight='bold')
ax2.grid(True, alpha=0.3)
mean_val = df['snr_db_mean'].mean()
median_val = df['snr_db_mean'].median()
ax2.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax2.axvline(median_val, color='green', linestyle='--', linewidth=2.5)

legend_elements = [
    Line2D([0], [0], color='red', linestyle='--', linewidth=2.5, label=f'Mean: {mean_val:.2f}'),
    Line2D([0], [0], color='green', linestyle='--', linewidth=2.5, label=f'Median: {median_val:.2f}')
]
ax2.legend(handles=legend_elements, loc='upper right', fontsize=9)

# 3. Clipping Rate Mean Distribution (Top Right)
ax3 = axes[0, 2]
ax3.hist(df['clipping_rate_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax3.set_xlabel('Clipping Rate Mean (%)', fontsize=11)
ax3.set_ylabel('Frequency', fontsize=11)
ax3.set_title('Clipping Rate Mean Distribution', fontsize=12, fontweight='bold')
ax3.grid(True, alpha=0.3)
mean_val = df['clipping_rate_mean'].mean()
median_val = df['clipping_rate_mean'].median()
ax3.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax3.axvline(median_val, color='green', linestyle='--', linewidth=2.5)

legend_elements = [
    Line2D([0], [0], color='red', linestyle='--', linewidth=2.5, label=f'Mean: {mean_val:.4f}'),
    Line2D([0], [0], color='green', linestyle='--', linewidth=2.5, label=f'Median: {median_val:.4f}')
]
ax3.legend(handles=legend_elements, loc='upper right', fontsize=9)

# 4. Silence Ratio Mean Distribution (Bottom Left)
ax4 = axes[1, 0]
ax4.hist(df['silence_ratio_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax4.set_xlabel('Silence Ratio Mean (%)', fontsize=11)
ax4.set_ylabel('Frequency', fontsize=11)
ax4.set_title('Silence Ratio Mean Distribution', fontsize=12, fontweight='bold')
ax4.grid(True, alpha=0.3)
mean_val = df['silence_ratio_mean'].mean()
median_val = df['silence_ratio_mean'].median()
ax4.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax4.axvline(median_val, color='green', linestyle='--', linewidth=2.5)

legend_elements = [
    Line2D([0], [0], color='red', linestyle='--', linewidth=2.5, label=f'Mean: {mean_val:.2f}'),
    Line2D([0], [0], color='green', linestyle='--', linewidth=2.5, label=f'Median: {median_val:.2f}')
]
ax4.legend(handles=legend_elements, loc='upper right', fontsize=9)

# 5. Dynamic Range Mean Distribution (Bottom Middle)
ax5 = axes[1, 1]
ax5.hist(df['dynamic_range_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax5.set_xlabel('Dynamic Range Mean (dB)', fontsize=11)
ax5.set_ylabel('Frequency', fontsize=11)
ax5.set_title('Dynamic Range Mean Distribution', fontsize=12, fontweight='bold')
ax5.grid(True, alpha=0.3)
mean_val = df['dynamic_range_mean'].mean()
median_val = df['dynamic_range_mean'].median()
ax5.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax5.axvline(median_val, color='green', linestyle='--', linewidth=2.5)

legend_elements = [
    Line2D([0], [0], color='red', linestyle='--', linewidth=2.5, label=f'Mean: {mean_val:.2f}'),
    Line2D([0], [0], color='green', linestyle='--', linewidth=2.5, label=f'Median: {median_val:.2f}')
]
ax5.legend(handles=legend_elements, loc='upper right', fontsize=9)

# 6. Spectral Centroid Mean Distribution (Bottom Right)
ax6 = axes[1, 2]
ax6.hist(df['spectral_centroid_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax6.set_xlabel('Spectral Centroid Mean (Hz)', fontsize=11)
ax6.set_ylabel('Frequency', fontsize=11)
ax6.set_title('Spectral Centroid Mean Distribution', fontsize=12, fontweight='bold')
ax6.grid(True, alpha=0.3)
mean_val = df['spectral_centroid_mean'].mean()
median_val = df['spectral_centroid_mean'].median()
ax6.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax6.axvline(median_val, color='green', linestyle='--', linewidth=2.5)

legend_elements = [
    Line2D([0], [0], color='red', linestyle='--', linewidth=2.5, label=f'Mean: {mean_val:.2f}'),
    Line2D([0], [0], color='green', linestyle='--', linewidth=2.5, label=f'Median: {median_val:.2f}')
]
ax6.legend(handles=legend_elements, loc='upper right', fontsize=9)

plt.tight_layout()

# Save the complete figure
plt.savefig('city_audio_quality_statistics.pdf', dpi=300, bbox_inches='tight')
print("Saved: city_audio_quality_statistics.pdf")

# Now create individual plots
# 1. Duration Mean
fig1, ax = plt.subplots(figsize=(10, 6))
ax.hist(df['duration_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax.set_xlabel('Duration Mean (seconds)', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
ax.set_title('Duration Mean Distribution Across Cities', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
mean_val = df['duration_mean'].mean()
median_val = df['duration_mean'].median()
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax.axvline(median_val, color='green', linestyle='--', linewidth=2.5)
y_pos = ax.get_ylim()[1] * 0.9
ax.text(mean_val, y_pos, f'  Mean: {mean_val:.2f}', color='red', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='red', linewidth=1.5))
ax.text(median_val, y_pos * 0.8, f'  Median: {median_val:.2f}', color='green', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='green', linewidth=1.5))
plt.tight_layout()
plt.savefig('city_duration_mean_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: city_duration_mean_distribution.pdf")
plt.close()

# 2. SNR Mean
fig2, ax = plt.subplots(figsize=(10, 6))
ax.hist(df['snr_db_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax.set_xlabel('SNR Mean (dB)', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
ax.set_title('SNR Mean Distribution Across Cities', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
mean_val = df['snr_db_mean'].mean()
median_val = df['snr_db_mean'].median()
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax.axvline(median_val, color='green', linestyle='--', linewidth=2.5)
y_pos = ax.get_ylim()[1] * 0.9
ax.text(mean_val, y_pos, f'  Mean: {mean_val:.2f}', color='red', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='red', linewidth=1.5))
ax.text(median_val, y_pos * 0.8, f'  Median: {median_val:.2f}', color='green', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='green', linewidth=1.5))
plt.tight_layout()
plt.savefig('city_snr_mean_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: city_snr_mean_distribution.pdf")
plt.close()

# 3. Clipping Rate Mean
fig3, ax = plt.subplots(figsize=(10, 6))
ax.hist(df['clipping_rate_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax.set_xlabel('Clipping Rate Mean (%)', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
ax.set_title('Clipping Rate Mean Distribution Across Cities', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
mean_val = df['clipping_rate_mean'].mean()
median_val = df['clipping_rate_mean'].median()
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax.axvline(median_val, color='green', linestyle='--', linewidth=2.5)
y_pos = ax.get_ylim()[1] * 0.9
ax.text(mean_val, y_pos, f'  Mean: {mean_val:.4f}', color='red', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='red', linewidth=1.5))
ax.text(median_val, y_pos * 0.8, f'  Median: {median_val:.4f}', color='green', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='green', linewidth=1.5))
plt.tight_layout()
plt.savefig('city_clipping_rate_mean_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: city_clipping_rate_mean_distribution.pdf")
plt.close()

# 4. Silence Ratio Mean
fig4, ax = plt.subplots(figsize=(10, 6))
ax.hist(df['silence_ratio_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax.set_xlabel('Silence Ratio Mean (%)', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
ax.set_title('Silence Ratio Mean Distribution Across Cities', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
mean_val = df['silence_ratio_mean'].mean()
median_val = df['silence_ratio_mean'].median()
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax.axvline(median_val, color='green', linestyle='--', linewidth=2.5)
y_pos = ax.get_ylim()[1] * 0.9
ax.text(mean_val, y_pos, f'  Mean: {mean_val:.2f}', color='red', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='red', linewidth=1.5))
ax.text(median_val, y_pos * 0.8, f'  Median: {median_val:.2f}', color='green', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='green', linewidth=1.5))
plt.tight_layout()
plt.savefig('city_silence_ratio_mean_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: city_silence_ratio_mean_distribution.pdf")
plt.close()

# 5. Dynamic Range Mean
fig5, ax = plt.subplots(figsize=(10, 6))
ax.hist(df['dynamic_range_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax.set_xlabel('Dynamic Range Mean (dB)', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
ax.set_title('Dynamic Range Mean Distribution Across Cities', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
mean_val = df['dynamic_range_mean'].mean()
median_val = df['dynamic_range_mean'].median()
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax.axvline(median_val, color='green', linestyle='--', linewidth=2.5)
y_pos = ax.get_ylim()[1] * 0.9
ax.text(mean_val, y_pos, f'  Mean: {mean_val:.2f}', color='red', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='red', linewidth=1.5))
ax.text(median_val, y_pos * 0.8, f'  Median: {median_val:.2f}', color='green', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='green', linewidth=1.5))
plt.tight_layout()
plt.savefig('city_dynamic_range_mean_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: city_dynamic_range_mean_distribution.pdf")
plt.close()

# 6. Spectral Centroid Mean
fig6, ax = plt.subplots(figsize=(10, 6))
ax.hist(df['spectral_centroid_mean'], bins=20, color=data_color, alpha=0.7, edgecolor='black')
ax.set_xlabel('Spectral Centroid Mean (Hz)', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
ax.set_title('Spectral Centroid Mean Distribution Across Cities', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
mean_val = df['spectral_centroid_mean'].mean()
median_val = df['spectral_centroid_mean'].median()
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2.5)
ax.axvline(median_val, color='green', linestyle='--', linewidth=2.5)
y_pos = ax.get_ylim()[1] * 0.9
ax.text(mean_val, y_pos, f'  Mean: {mean_val:.2f}', color='red', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='red', linewidth=1.5))
ax.text(median_val, y_pos * 0.8, f'  Median: {median_val:.2f}', color='green', fontsize=11,
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white', edgecolor='green', linewidth=1.5))
plt.tight_layout()
plt.savefig('city_spectral_centroid_mean_distribution.pdf', dpi=300, bbox_inches='tight')
print("Saved: city_spectral_centroid_mean_distribution.pdf")
plt.close()

# Print summary statistics
print("\n" + "="*60)
print("SUMMARY STATISTICS ACROSS CITIES")
print("="*60)
print(f"\nDuration Mean (seconds):")
print(f"  Mean: {df['duration_mean'].mean():.2f}, Median: {df['duration_mean'].median():.2f}, Std: {df['duration_mean'].std():.2f}")
print(f"\nSNR Mean (dB):")
print(f"  Mean: {df['snr_db_mean'].mean():.2f}, Median: {df['snr_db_mean'].median():.2f}, Std: {df['snr_db_mean'].std():.2f}")
print(f"\nClipping Rate Mean (%):")
print(f"  Mean: {df['clipping_rate_mean'].mean():.4f}, Median: {df['clipping_rate_mean'].median():.4f}, Std: {df['clipping_rate_mean'].std():.4f}")
print(f"\nSilence Ratio Mean (%):")
print(f"  Mean: {df['silence_ratio_mean'].mean():.2f}, Median: {df['silence_ratio_mean'].median():.2f}, Std: {df['silence_ratio_mean'].std():.2f}")
print(f"\nDynamic Range Mean (dB):")
print(f"  Mean: {df['dynamic_range_mean'].mean():.2f}, Median: {df['dynamic_range_mean'].median():.2f}, Std: {df['dynamic_range_mean'].std():.2f}")
print(f"\nSpectral Centroid Mean (Hz):")
print(f"  Mean: {df['spectral_centroid_mean'].mean():.2f}, Median: {df['spectral_centroid_mean'].median():.2f}, Std: {df['spectral_centroid_mean'].std():.2f}")

print("\n" + "="*60)
print("All graphs have been generated and saved!")
print("="*60)
print("\nFiles created:")
print("1. city_audio_quality_statistics.pdf (combined view)")
print("2. city_duration_mean_distribution.pdf")
print("3. city_snr_mean_distribution.pdf")
print("4. city_clipping_rate_mean_distribution.pdf")
print("5. city_silence_ratio_mean_distribution.pdf")
print("6. city_dynamic_range_mean_distribution.pdf")
print("7. city_spectral_centroid_mean_distribution.pdf")
# Out:
# Total cities in dataset: 60
# ...

# %% [markdown]
# # Plot cities bubble

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# --- CONFIGURATION VARIABLES ---
# Control bubble size here.
# 1.0 = Original size
# 0.3 = 30% of original size (70% smaller)
BUBBLE_SIZE_FACTOR = 0.55

# City coordinates mapping
CITY_COORDINATES = {
    'Algeria': {
        'Algiers': (36.6997, 3.0576),
        'Batna': (35.556, 6.1741),
        'Oran': (35.6911, -0.6417),
        'Annaba': (36.9, 7.7667),
        'Blida': (36.4667, 2.8167),
        'Constantine': (36.365, 6.6147),
        'Biskra': (34.8504, 5.7281),
        'Djelfa': (34.6728, 3.263),
        'Sétif': (36.1911, 5.4137)
    },
    'Bahrain': {'Manama': (26.2279, 50.5857)},
    'Egypt': {
        'Cairo': (30.0626, 31.2497),
        'Alexandria': (31.2018, 29.9158)
    },
    'Iraq': {
        'Basra': (30.5085, 47.7804),
        'Baghdad': (33.3406, 44.4009)
    },
    'Jordan': {
        'Amman': (31.9552, 35.945),
        'Irbid': (32.556, 35.848)
    },
    'Kuwait': {'Kuwait (City)': (29.3759, 47.9774)},
    'Lebanon': {
        'Beirut': (33.8938, 35.5018),
        'Cheikh Taba': (34.5333, 36.0833)
    },
    'Libya': {
        'Tripoli': (32.8872, 13.1913),
        'Benghazi': (32.1167, 20.0667)
    },
    'Morocco': {
        'Fes': (34.0333, -5),
        'Casablanca': (33.5731, -7.5898),
        'Rabat': (34.0209, -6.8416),
        'Marrakech': (31.6295, -7.9811),
        'Tanger (Tangier)': (35.7796, -5.8339)
    },
    'Oman': {'Oman (Muscat)': (23.5841, 58.4078)},
    'Palestine': {
        'Nablus': (32.2211, 35.2544),
        'Hebron': (31.5294, 35.0938),
        'Ramallah': (31.8996, 35.2042),
        'Jerusalem': (31.769, 35.2163),
        'Qaza (Gaza City)': (31.5016, 34.4667)
    },
    'Qatar': {'Doha': (25.2854, 51.531)},
    'Saudi Arabia': {
        'Riyadh': (24.7136, 46.6753),
        'Jeddah': (21.4901, 39.1862),
        'Makkah (Mecca)': (21.4266, 39.8256)
    },
    'Somalia': {
        'Shabelle (Lower Shabelle region)': (1.7683, 44.39),
        'Mogadishu': (2.0371, 45.3438),
        'Daljir (Mogadishu area)': (2.0371, 45.3438)
    },
    'Sudan': {
        'El Obeid': (13.1842, 30.2167),
        'Omdurman': (15.6445, 32.4777),
        'Khartoum': (15.5007, 32.5599),
        'Wad Medani': (14.4012, 33.5199),
        'Port Sudan': (19.6175, 37.2164)
    },
    'Syria': {
        'Aleppo': (36.2012, 37.1612),
        'Damascus': (33.5104, 36.2783)
    },
    'Tunisia': {'Tunis': (36.819, 10.1658)},
    'UAE': {
        'Ajman': (25.4052, 55.5136),
        'Dubai': (25.2048, 55.2708),
        'Fujairah': (25.1288, 56.3265),
        'Abu Dhabi': (24.4539, 54.3773),
        'Sharjah': (25.3463, 55.4209)
    },
    'Yemen': {
        'Sana\'a': (15.3694, 44.191),
        'Aden': (12.7794, 45.0367),
        'Taiz': (13.5794, 44.0207),
        'Al-Hodeidah': (14.7978, 42.9545)
    }
}

def get_coordinates(city):
    """Get latitude and longitude for a city"""
    city_mapping = {
        'alger': 'Algiers', 'batna': 'Batna', 'djelfa': 'Djelfa',
        'biskra': 'Biskra', 'Tanger': 'Tanger (Tangier)', 'Ajman': 'Ajman',
        'Jeddah': 'Jeddah', 'Qaza': 'Qaza (Gaza City)', 'amman': 'Amman',
        'kuwait': 'Kuwait (City)', 'Muscat': 'Oman (Muscat)',
        'Abu Dhabi': 'Abu Dhabi', 'sanaa': 'Sana\'a',
        'cheikh_taba': 'Cheikh Taba', 'Riyadh': 'Riyadh',
        'manama_nation-wide': 'Manama', 'constantine': 'Constantine',
        'setif': 'Sétif', 'tunis': 'Tunis', 'taiz': 'Taiz',
        'beirut': 'Beirut', 'hebron': 'Hebron',
        'Shabelle': 'Shabelle (Lower Shabelle region)',
        'manama': 'Manama', 'bilda': 'Blida', 'Somali': 'Mogadishu',
        'daljir': 'Daljir (Mogadishu area)', 'aden': 'Aden'
    }

    mapped_city = city_mapping.get(city, city)

    for country, cities in CITY_COORDINATES.items():
        if mapped_city in cities:
            return cities[mapped_city]

    return None, None

# SNR Data
snr_data = {
    'Doha': 10.88470447, 'manama': 7.569547164, 'alger': 18.70433247,
    'El Obeid': 1.10934359, 'manama_nation-wide': 17.06221192, 'Cairo': 13.4889671,
    'biskra': -1.822794781, 'djelfa': 21.65324887, 'Baghdad': 11.02038495,
    'Annaba': 1.088025939, 'Omdurman': 14.13592151, 'Fes': 13.57226775,
    'Jeddah': 19.20666224, 'setif': 15.52462781, 'batna': 19.53195714,
    'Riyadh': 25.58813235, 'amman': 17.75795957, 'Ajman': 17.41652031,
    'kuwait': 24.97677097, 'Alexandria': 17.01306096, 'Basra': 14.97152833,
    'Oran': 14.97431249, 'hebron': 11.68888991, 'Sharjah': 18.82551063,
    'Ramallah': 24.17123566, 'Casablanca': 15.85778573, 'constantine': 9.370206333,
    'bilda': 16.15269732, 'Shabelle': 8.825725869, 'Aleppo': 11.98425705,
    'Wad Medani': 13.61884904, 'sanaa': 15.17476619, 'Port Sudan': 25.80316428,
    'Somali': 14.24148087, 'taiz': 13.92884896, 'Muscat': 9.392287901,
    'beirut': 12.59389179, 'Abu Dhabi': 17.07174236, 'Makkah': 17.41165615,
    'Nablus': 18.44430307, 'Tripoli': 12.59919987, 'cheikh_taba': 12.28642968,
    'Fujairah': 16.0088016, 'Dubai': 15.25793899, 'Damascus': 18.62135987,
    'tunis': 8.309239941, 'Marrakech': 15.05960802, 'Khartoum': 16.27696548,
    'Al-Hodeidah': 18.32662662, 'Rabat': 17.84379814, 'aden': 17.0528406,
    'Benghazi': 12.02279192, 'Tanger': 9.981625733, 'Jerusalem': 3.768460179,
    'Irbid': 12.63687262, 'Mogadishu': 12.62406742, 'Qaza': 15.70245556,
    'daljir': 31.28395353
}

# Record Counts
record_counts = {
    'manama_nation-wide': 307, 'alger': 306, 'El Obeid': 260, 'Cairo': 196,
    'Doha': 174, 'djelfa': 147, 'Jeddah': 144, 'biskra': 141, 'Fes': 138,
    'amman': 122, 'Riyadh': 118, 'kuwait': 113, 'Annaba': 103, 'Alexandria': 98,
    'Ajman': 91, 'Omdurman': 90, 'batna': 88, 'Sharjah': 84, 'Basra': 84,
    'setif': 80, 'Casablanca': 76, 'manama': 75, 'Baghdad': 74, 'Ramallah': 72,
    'Aleppo': 71, 'hebron': 70, 'sanaa': 59, 'Shabelle': 58, 'Wad Medani': 57,
    'Port Sudan': 55, 'Oran': 52, 'Nablus': 51, 'taiz': 50, 'Muscat': 50,
    'constantine': 47, 'beirut': 46, 'Abu Dhabi': 46, 'Tripoli': 46, 'bilda': 44,
    'Fujairah': 41, 'Damascus': 40, 'cheikh_taba': 40, 'Marrakech': 38,
    'Al-Hodeidah': 36, 'Dubai': 36, 'Khartoum': 34, 'Rabat': 34, 'tunis': 32,
    'Benghazi': 30, 'Tanger': 20, 'Irbid': 18, 'Jerusalem': 14, 'Mogadishu': 9,
    'Qaza': 7, 'Somali': 3, 'daljir': 1
}

# Prepare data
plot_data = []
for city in record_counts.keys():
    lat, lon = get_coordinates(city)
    if lat is not None and lon is not None:
        plot_data.append({
            'city': city,
            'lat': lat,
            'lon': lon,
            'snr': snr_data.get(city, 0),
            'count': record_counts[city]
        })

df = pd.DataFrame(plot_data)

# Create custom hover text
hover_text = []
for idx, row in df.iterrows():
    text = f"<b>{row['city']}</b><br>"
    text += f"Records: {row['count']}<br>"
    text += f"SNR dB: {row['snr']:.2f}<br>"
    text += f"Lat: {row['lat']:.4f}<br>"
    text += f"Lon: {row['lon']:.4f}"
    hover_text.append(text)

# Create the figure
fig = go.Figure()

# Add scatter geo
fig.add_trace(go.Scattergeo(
    lon=df['lon'],
    lat=df['lat'],
    text=hover_text,
    mode='markers',
    marker=dict(
        # Applied the scaling factor here
        size=(df['count'] / 3) * BUBBLE_SIZE_FACTOR,
        color=df['snr'],
        colorscale='RdYlGn',
        cmin=df['snr'].min(),
        cmax=df['snr'].max(),
        colorbar=dict(
            title=dict(
                text="SNR dB Mean",
                # Changed to dark gray
                font=dict(size=14, color='rgb(60, 60, 60)', family='Arial Black')
            ),
            # Changed to dark gray
            tickfont=dict(size=12, color='rgb(60, 60, 60)'),
            thickness=20,
            len=0.7,
            # Changed to white
            bgcolor='rgba(255, 255, 255, 0.9)',
            # Changed to gray
            bordercolor='rgb(200, 200, 200)',
            borderwidth=1
        ),
        # Darker border for visibility on white map
        line=dict(width=0.5, color='rgb(50, 50, 50)'),
        opacity=0.85
    ),
    hovertemplate='%{text}<extra></extra>',
    name=''
))

# Update layout for WHITE theme map style
fig.update_geos(
    resolution=50,
    showcoastlines=True,
    coastlinecolor="rgba(100, 100, 100, 0.5)", # Darker coastlines
    coastlinewidth=1,
    showland=True,
    landcolor="rgb(245, 245, 245)", # Light Gray Land
    showocean=True,
    oceancolor="rgb(255, 255, 255)", # White Ocean
    showcountries=True,
    countrycolor="rgba(100, 100, 100, 0.3)", # Darker country borders
    countrywidth=0.5,
    showlakes=True,
    lakecolor="rgb(255, 255, 255)", # White lakes
    showrivers=False,
    projection_type="natural earth",
    lonaxis=dict(range=[-15, 65]),
    lataxis=dict(range=[-5, 42]),
    bgcolor="white" # White background
)

# Update overall layout
fig.update_layout(
    title=dict(
        text="<b>Middle East & North Africa: Signal Quality Distribution</b><br><sub>Bubble Size = Record Count | Color = SNR dB Mean</sub>",
        # Changed to black
        font=dict(size=22, color='black', family='Arial Black'),
        x=0.5,
        xanchor='center'
    ),
    paper_bgcolor='white', # White paper
    plot_bgcolor='white', # White plot
    font=dict(color='black', size=12), # Black font
    height=800,
    margin=dict(l=0, r=0, t=80, b=0),
    showlegend=False
)

# Show the figure
fig.show()

# Optional: Save as HTML
fig.write_html("mena_signal_quality_map_white.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# --- CONFIGURATION VARIABLES ---
# Control bubble size here.
# 0.3 = 30% of original size (70% smaller)
BUBBLE_SIZE_FACTOR = 0.70
# Minimum size in pixels (so single records don't disappear)
MIN_BUBBLE_SIZE = 3

# City coordinates mapping
CITY_COORDINATES = {
    'Algeria': {
        'Algiers': (36.6997, 3.0576),
        'Batna': (35.556, 6.1741),
        'Oran': (35.6911, -0.6417),
        'Annaba': (36.9, 7.7667),
        'Blida': (36.4667, 2.8167),
        'Constantine': (36.365, 6.6147),
        'Biskra': (34.8504, 5.7281),
        'Djelfa': (34.6728, 3.263),
        'Sétif': (36.1911, 5.4137)
    },
    'Bahrain': {'Manama': (26.2279, 50.5857)},
    'Egypt': {
        'Cairo': (30.0626, 31.2497),
        'Alexandria': (31.2018, 29.9158)
    },
    'Iraq': {
        'Basra': (30.5085, 47.7804),
        'Baghdad': (33.3406, 44.4009)
    },
    'Jordan': {
        'Amman': (31.9552, 35.945),
        'Irbid': (32.556, 35.848)
    },
    'Kuwait': {'Kuwait (City)': (29.3759, 47.9774)},
    'Lebanon': {
        'Beirut': (33.8938, 35.5018),
        'Cheikh Taba': (34.5333, 36.0833)
    },
    'Libya': {
        'Tripoli': (32.8872, 13.1913),
        'Benghazi': (32.1167, 20.0667)
    },
    'Morocco': {
        'Fes': (34.0333, -5),
        'Casablanca': (33.5731, -7.5898),
        'Rabat': (34.0209, -6.8416),
        'Marrakech': (31.6295, -7.9811),
        'Tanger (Tangier)': (35.7796, -5.8339)
    },
    'Oman': {'Oman (Muscat)': (23.5841, 58.4078)},
    'Palestine': {
        'Nablus': (32.2211, 35.2544),
        'Hebron': (31.5294, 35.0938),
        'Ramallah': (31.8996, 35.2042),
        'Jerusalem': (31.769, 35.2163),
        'Qaza (Gaza City)': (31.5016, 34.4667)
    },
    'Qatar': {'Doha': (25.2854, 51.531)},
    'Saudi Arabia': {
        'Riyadh': (24.7136, 46.6753),
        'Jeddah': (21.4901, 39.1862),
        'Makkah (Mecca)': (21.4266, 39.8256)
    },
    'Somalia': {
        'Shabelle (Lower Shabelle region)': (1.7683, 44.39),
        'Mogadishu': (2.0371, 45.3438),
        'Daljir (Mogadishu area)': (2.0371, 45.3438)
    },
    'Sudan': {
        'El Obeid': (13.1842, 30.2167),
        'Omdurman': (15.6445, 32.4777),
        'Khartoum': (15.5007, 32.5599),
        'Wad Medani': (14.4012, 33.5199),
        'Port Sudan': (19.6175, 37.2164)
    },
    'Syria': {
        'Aleppo': (36.2012, 37.1612),
        'Damascus': (33.5104, 36.2783)
    },
    'Tunisia': {'Tunis': (36.819, 10.1658)},
    'UAE': {
        'Ajman': (25.4052, 55.5136),
        'Dubai': (25.2048, 55.2708),
        'Fujairah': (25.1288, 56.3265),
        'Abu Dhabi': (24.4539, 54.3773),
        'Sharjah': (25.3463, 55.4209)
    },
    'Yemen': {
        'Sana\'a': (15.3694, 44.191),
        'Aden': (12.7794, 45.0367),
        'Taiz': (13.5794, 44.0207),
        'Al-Hodeidah': (14.7978, 42.9545)
    }
}

def get_coordinates(city):
    """Get latitude and longitude for a city"""
    city_mapping = {
        'alger': 'Algiers', 'batna': 'Batna', 'djelfa': 'Djelfa',
        'biskra': 'Biskra', 'Tanger': 'Tanger (Tangier)', 'Ajman': 'Ajman',
        'Jeddah': 'Jeddah', 'Qaza': 'Qaza (Gaza City)', 'amman': 'Amman',
        'kuwait': 'Kuwait (City)', 'Muscat': 'Oman (Muscat)',
        'Abu Dhabi': 'Abu Dhabi', 'sanaa': 'Sana\'a',
        'cheikh_taba': 'Cheikh Taba', 'Riyadh': 'Riyadh',
        'manama_nation-wide': 'Manama', 'constantine': 'Constantine',
        'setif': 'Sétif', 'tunis': 'Tunis', 'taiz': 'Taiz',
        'beirut': 'Beirut', 'hebron': 'Hebron',
        'Shabelle': 'Shabelle (Lower Shabelle region)',
        'manama': 'Manama', 'bilda': 'Blida', 'Somali': 'Mogadishu',
        'daljir': 'Daljir (Mogadishu area)', 'aden': 'Aden'
    }

    mapped_city = city_mapping.get(city, city)

    for country, cities in CITY_COORDINATES.items():
        if mapped_city in cities:
            return cities[mapped_city]

    return None, None

# SNR Data
snr_data = {
    'Doha': 10.88470447, 'manama': 7.569547164, 'alger': 18.70433247,
    'El Obeid': 1.10934359, 'manama_nation-wide': 17.06221192, 'Cairo': 13.4889671,
    'biskra': -1.822794781, 'djelfa': 21.65324887, 'Baghdad': 11.02038495,
    'Annaba': 1.088025939, 'Omdurman': 14.13592151, 'Fes': 13.57226775,
    'Jeddah': 19.20666224, 'setif': 15.52462781, 'batna': 19.53195714,
    'Riyadh': 25.58813235, 'amman': 17.75795957, 'Ajman': 17.41652031,
    'kuwait': 24.97677097, 'Alexandria': 17.01306096, 'Basra': 14.97152833,
    'Oran': 14.97431249, 'hebron': 11.68888991, 'Sharjah': 18.82551063,
    'Ramallah': 24.17123566, 'Casablanca': 15.85778573, 'constantine': 9.370206333,
    'bilda': 16.15269732, 'Shabelle': 8.825725869, 'Aleppo': 11.98425705,
    'Wad Medani': 13.61884904, 'sanaa': 15.17476619, 'Port Sudan': 25.80316428,
    'Somali': 14.24148087, 'taiz': 13.92884896, 'Muscat': 9.392287901,
    'beirut': 12.59389179, 'Abu Dhabi': 17.07174236, 'Makkah': 17.41165615,
    'Nablus': 18.44430307, 'Tripoli': 12.59919987, 'cheikh_taba': 12.28642968,
    'Fujairah': 16.0088016, 'Dubai': 15.25793899, 'Damascus': 18.62135987,
    'tunis': 8.309239941, 'Marrakech': 15.05960802, 'Khartoum': 16.27696548,
    'Al-Hodeidah': 18.32662662, 'Rabat': 17.84379814, 'aden': 17.0528406,
    'Benghazi': 12.02279192, 'Tanger': 9.981625733, 'Jerusalem': 3.768460179,
    'Irbid': 12.63687262, 'Mogadishu': 12.62406742, 'Qaza': 15.70245556,
    'daljir': 31.28395353
}

# Record Counts
record_counts = {
    'manama_nation-wide': 307, 'alger': 306, 'El Obeid': 260, 'Cairo': 196,
    'Doha': 174, 'djelfa': 147, 'Jeddah': 144, 'biskra': 141, 'Fes': 138,
    'amman': 122, 'Riyadh': 118, 'kuwait': 113, 'Annaba': 103, 'Alexandria': 98,
    'Ajman': 91, 'Omdurman': 90, 'batna': 88, 'Sharjah': 84, 'Basra': 84,
    'setif': 80, 'Casablanca': 76, 'manama': 75, 'Baghdad': 74, 'Ramallah': 72,
    'Aleppo': 71, 'hebron': 70, 'sanaa': 59, 'Shabelle': 58, 'Wad Medani': 57,
    'Port Sudan': 55, 'Oran': 52, 'Nablus': 51, 'taiz': 50, 'Muscat': 50,
    'constantine': 47, 'beirut': 46, 'Abu Dhabi': 46, 'Tripoli': 46, 'bilda': 44,
    'Fujairah': 41, 'Damascus': 40, 'cheikh_taba': 40, 'Marrakech': 38,
    'Al-Hodeidah': 36, 'Dubai': 36, 'Khartoum': 34, 'Rabat': 34, 'tunis': 32,
    'Benghazi': 30, 'Tanger': 20, 'Irbid': 18, 'Jerusalem': 14, 'Mogadishu': 9,
    'Qaza': 7, 'Somali': 3, 'daljir': 1
}

# Prepare data
plot_data = []
for city in record_counts.keys():
    lat, lon = get_coordinates(city)
    if lat is not None and lon is not None:
        plot_data.append({
            'city': city,
            'lat': lat,
            'lon': lon,
            'snr': snr_data.get(city, 0),
            'count': record_counts[city]
        })

df = pd.DataFrame(plot_data)

# Calculate bubble sizes
# 1. Base size is (count / 3)
# 2. Multiply by user factor
# 3. Ensure minimum size (np.maximum) so 1-record cities are visible
raw_sizes = (df['count'] / 3) * BUBBLE_SIZE_FACTOR
df['bubble_size'] = np.maximum(raw_sizes, MIN_BUBBLE_SIZE)

# Create custom hover text
hover_text = []
for idx, row in df.iterrows():
    text = f"<b>{row['city']}</b><br>"
    text += f"Records: {row['count']}<br>"
    text += f"SNR dB: {row['snr']:.2f}<br>"
    text += f"Lat: {row['lat']:.4f}<br>"
    text += f"Lon: {row['lon']:.4f}"
    hover_text.append(text)

# Create the figure
fig = go.Figure()

# Add Scattermapbox (Tile-based map)
fig.add_trace(go.Scattermapbox(
    lon=df['lon'],
    lat=df['lat'],
    text=hover_text,
    mode='markers',
    marker=dict(
        size=df['bubble_size'],
        color=df['snr'],
        colorscale='RdYlGn',
        cmin=df['snr'].min(),
        cmax=df['snr'].max(),
        colorbar=dict(
            title=dict(
                text="SNR dB",
                font=dict(size=12, color='rgb(60, 60, 60)', family='Arial')
            ),
            tickfont=dict(size=10, color='rgb(60, 60, 60)'),
            thickness=15,
            len=0.6,
            bgcolor='rgba(255, 255, 255, 0.9)',
            x=0.02, # Move colorbar to left side slightly
            xanchor='left',
        ),
        opacity=0.85
    ),
    hovertemplate='%{text}<extra></extra>',
    name=''
))

# Update layout to use Mapbox
fig.update_layout(
    # 'carto-positron' is the white theme style that includes country labels
    mapbox_style="carto-positron",
    mapbox_zoom=3,
    mapbox_center={"lat": 25.0, "lon": 30.0}, # Centered on MENA

    title=dict(
        text="",
        font=dict(size=20, color='black', family='Arial'),
        x=0.5,
        xanchor='center',
        y=0.95
    ),
    paper_bgcolor='white',
    plot_bgcolor='white',
    font=dict(color='black', size=12),
    height=800,
    margin=dict(l=0, r=0, t=50, b=0),
    showlegend=False
)

# Show the figure
fig.show()

# Optional: Save as HTML
fig.write_html("mena_signal_quality_labeled_map.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
